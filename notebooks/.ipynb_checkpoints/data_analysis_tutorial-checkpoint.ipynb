# %% [markdown]
# # Intro to data analysis with pandas

# %% [markdown]
# # In-depth pandas tutorial
# [Giant pandas tutorial](https://www.youtube.com/watch?v=oGzU688xCUs) and [attendant notes](https://github.com/chendaniely/scipy-2017-tutorial-pandas) available at the links.

# %% [markdown]
# # Imports
# Allow plots in the notebook itself, and enable some helpful functions

# %%
# %reset -f
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # High-res graphs (rendered irrelevant by svg option below)
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':'tight'} # No extra white space
# %config InlineBackend.figure_format = 'svg' # 'png' is default

import warnings
warnings.filterwarnings('ignore') # Because we are adults
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset("tips")
data.head()  # show first n entries (default is 5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Histograms

# %%
data["tip"].hist(by=data["sex"], sharex=True, sharey=True)
sns.despine()  # Remove top and right side of box

plt.show()  # Somewhat redundant in this context, but suppresses annoying text output.

# %% [markdown]
# ## Overlaid histograms

# %%
grouped_by_sex = data.groupby("sex")

# You can also add several arguments below like bins=20, or normed=True
figure, axes = grouped_by_sex["tip"].plot(
    kind="hist", normed=False, alpha=0.5, legend=True
)

# Re-label legend entries, move legend to right-middle
axes.legend(["Men", "Women"], loc=(0.75, 0.5))

sns.despine()
plt.show()

# %% [markdown]
# ## Descriptive statistics

# %%
grouped_by_sex["tip"].describe()
# Out:
#         count      mean       std  min  25%   50%   75%   max
# sex
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5

# %% [markdown]
# ## Subsetting data
# Let's get the tips given on Sunday at dinner time only.

# %%
sunday_dinner_tips = data.tip[(data.day == "Sun") & (data.time == "Dinner")]

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Add new column
# Add a new column showing the percentage of the total bill tipped using a lambda expression. Naturally, you can also accomplish this by defining a named function.

# %%
data["tip_percentage"] = data.apply(
    lambda row: row["tip"] / row["total_bill"] * 100, axis=1
)
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765

# %% [markdown]
# ## Deleting columns
# Delete that new tip percentage column.

# %%
del data["tip_percentage"]
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Inferential Statistics
# Examples of inferential statistics using statsmodels. Note that there are some recent and annoying breaking changes between pandas and numpy when dealing with pandas's "categorical" data type.

# %% [markdown]
# ## ANOVA
# Perform an ANOVA using syntax akin to that of R.

# %% [markdown]
# First, figure out which columns have the annoying "categorical" data type.

# %%
data.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# Second, convert those to strings (will show as "object", which numpy can actually understand).

# %%
categories = ["sex", "smoker", "day", "time"]

for category in categories:
    data[category] = data[category].astype(str)

data.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %% [markdown]
# Now run the ANOVA.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = "tip ~ day * smoker"
lm = ols(model, data=data).fit()
# lm.summary() # to show regression results
table = sm.stats.anova_lm(lm, typ=2)

display(table)
# Out:
#                 sum_sq     df         F    PR(>F)
# day           9.838737    3.0  1.715263  0.164532
# smoker        0.329215    1.0  0.172184  0.678555
# day:smoker    4.125773    3.0  0.719278  0.541351
# Residual    451.231616  236.0       NaN       NaN

# %% [markdown]
# ## Table aesthetics
# Make the table prettier and more intelligible.

# %%
def color_significant_green(val, alpha=0.05):
    if val < alpha:
        color = "green"
    else:
        color = "black"
    return "color: %s" % color


def bold_significant(val, alpha=0.05):
    if val < alpha:
        font_weight = "bold"
    else:
        font_weight = "normal"
    return "font-weight: %s" % font_weight


(
    table.style.applymap(color_significant_green, alpha=0.05, subset=["PR(>F)"])
    .applymap(bold_significant, alpha=0.05, subset=["PR(>F)"])
    .format("{:.3f}", subset=["sum_sq", "F", "PR(>F)"])  # show only 3 decimal places
)
# Out:
# <style  type="text/css" >
#     #T_f711880c_2e6f_11e9_bdff_f40669f160d4row0_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_f711880c_2e6f_11e9_bdff_f40669f160d4row1_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_f711880c_2e6f_11e9_bdff_f40669f160d4row2_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_f711880c_2e6f_11e9_bdff_f40669f160d4row3_col3 {
#             color:  black;
#             font-weight:  normal;
#         }</style><table id="T_f711880c_2e6f_11e9_bdff_f40669f160d4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum_sq</th>        <th class="col_heading level0 col1" >df</th>        <th class="col_heading level0 col2" >F</th>        <th class="col_heading level0 col3" >PR(>F)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f711880c_2e6f_11e9_bdff_f40669f160d4level0_row0" class="row_heading level0 row0" >day</th>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row0_col0" class="data row0 col0" >9.839</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row0_col2" class="data row0 col2" >1.715</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row0_col3" class="data row0 col3" >0.165</td>
#             </tr>
#             <tr>
#                         <th id="T_f711880c_2e6f_11e9_bdff_f40669f160d4level0_row1" class="row_heading level0 row1" >smoker</th>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row1_col0" class="data row1 col0" >0.329</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row1_col2" class="data row1 col2" >0.172</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row1_col3" class="data row1 col3" >0.679</td>
#             </tr>
#             <tr>
#                         <th id="T_f711880c_2e6f_11e9_bdff_f40669f160d4level0_row2" class="row_heading level0 row2" >day:smoker</th>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row2_col0" class="data row2 col0" >4.126</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row2_col2" class="data row2 col2" >0.719</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row2_col3" class="data row2 col3" >0.541</td>
#             </tr>
#             <tr>
#                         <th id="T_f711880c_2e6f_11e9_bdff_f40669f160d4level0_row3" class="row_heading level0 row3" >Residual</th>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row3_col0" class="data row3 col0" >451.232</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row3_col1" class="data row3 col1" >236</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_f711880c_2e6f_11e9_bdff_f40669f160d4row3_col3" class="data row3 col3" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## T-tests

# %%
from numpy import sqrt
from scipy.stats import ttest_ind


def cohens_d(t, n):
    return 2 * t / sqrt(n - 2)


# Set up empty results table
columns = ["n", "t", "p", "d"]
index = []
results = pd.DataFrame(index=index, columns=columns)

# Get data for t-test
male_tips = data[data["sex"] == "Male"]["tip"]
female_tips = data[data["sex"] == "Female"]["tip"]

# Perform t-test and surrounding calculations
n = male_tips.count() + female_tips.count()
df = n - 2
t, p = ttest_ind(male_tips, female_tips)
d = cohens_d(t, n)

# Add data to table
comparison = "Male vs. Female"
results.loc[comparison] = [n, t, p, d]

# Output pretty table
(
    results.style.applymap(color_significant_green, subset=["p"])
    .applymap(bold_significant, subset=["p"])
    .format("{:.3f}", subset=["t", "p", "d"])
)
# Out:
# <style  type="text/css" >
#     #T_f7aa5230_2e6f_11e9_9898_f40669f160d4row0_col2 {
#             color:  black;
#             font-weight:  normal;
#         }</style><table id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >n</th>        <th class="col_heading level0 col1" >t</th>        <th class="col_heading level0 col2" >p</th>        <th class="col_heading level0 col3" >d</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4level0_row0" class="row_heading level0 row0" >Male vs. Female</th>
#                         <td id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4row0_col0" class="data row0 col0" >244</td>
#                         <td id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4row0_col1" class="data row0 col1" >1.388</td>
#                         <td id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4row0_col2" class="data row0 col2" >0.166</td>
#                         <td id="T_f7aa5230_2e6f_11e9_9898_f40669f160d4row0_col3" class="data row0 col3" >0.178</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Place statistics in text with Markdown

# %%
from IPython.display import Markdown

inequality_symbol = "="


def report_t_test(df, t, p, d, alpha=0.001):
    if p < alpha:
        p = 0.001
        inequality_symbol = "<"
    else:
        inequality_symbol = "="

    T = format(t, ".2f").lstrip("0")  # 2 decimal places, no leading 0
    P = format(p, ".3f").lstrip("0")
    D = format(d, ".3f").lstrip("0")
    DF = format(df, "d")  # integer

    output = f"*t*({DF})={T}, _p_{inequality_symbol}{P}, *d*={D}"
    display(Markdown(output))


report_t_test(df, t, p, d)
# Out:
# *t*(242)=1.39, _p_=.166, *d*=.178

# %% [markdown]
# And in plain markdown:
# _t_({{n-2}})={{format(t, '.2f').lstrip('0')}}, *p*{{inequality_symbol}}{{format(p, '.3f').lstrip('0')}}, *d*={{format(d, '.3f').lstrip('0')}}
#
# <div class="alert alert-block alert-info">
# Note that you can copy paste such outputs directly into Word with no loss of formatting!
# </div>

# %% [markdown]
# ## Repeated Measures ANOVA
# [See example here.](https://www.marsja.se/repeated-measures-anova-in-python-using-statsmodels/)

# %%
import pandas as pd
import numpy as np
import statsmodels
from statsmodels.stats.anova import AnovaRM
statsmodels.__version__
# Out:
# '0.9.0'

# %%
N = 20
P = [1, 2]

values = [998, 511]

sub_id = [i + 1 for i in range(N)] * len(P)
mus = np.concatenate([np.repeat(value, N) for value in values]).tolist()
rt = np.random.normal(mus, scale=112.0, size=N * len(P)).tolist()
iv = np.concatenate([np.array([p] * N) for p in P]).tolist()

df = pd.DataFrame({"id": sub_id, "rt": rt, "iv": iv})

# %%
aovrm = AnovaRM(df, depvar="rt", subject="id", within=["iv"])
fit = aovrm.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#               Anova
# =================================
#    Num DF  Den DF F Value  Pr > F
# ---------------------------------
# iv 1.0000 19.0000 225.3254 0.0000
# =================================
#
# """

# %% [markdown]
# # dfply
# For those of you who are familiar with R and the tidyverse, the [dfply package](https://github.com/kieferk/dfply) allows you to have dplyr-like piping in Python. The pipe operator for this package is `>>`, while the result of each computation step is given by `X`. `>>=` is used for in-place assignment. All the documentation is available at the link; I'm just going to go over some useful basics here.

# %%
from dfply import *

diamonds >> head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Selection

# %% [markdown]
# Select two of the columns using `X` to represent the piped data frame.

# %%
diamonds >> select(X.cut, X.carat) >> head()
# Out:
#        cut  carat
# 0    Ideal   0.23
# 1  Premium   0.21
# 2     Good   0.23
# 3  Premium   0.29
# 4     Good   0.31

# %% [markdown]
# Alternatively, you can use an array of field names.

# %%
diamonds >> select(["cut", "carat"]) >> head()
# Out:
#        cut  carat
# 0    Ideal   0.23
# 1  Premium   0.21
# 2     Good   0.23
# 3  Premium   0.29
# 4     Good   0.31

# %% [markdown]
# Or we can refer to the columns by their numerical index.

# %%
diamonds >> select(1, 0) >> head()
# Out:
#        cut  carat
# 0    Ideal   0.23
# 1  Premium   0.21
# 2     Good   0.23
# 3  Premium   0.29
# 4     Good   0.31

# %% [markdown]
# ## Dropping
# Works the same way as `select`.

# %%
# drop cut (1), price, x and y
diamonds >> drop(1, X.price, ["x", "y"]) >> head()
# Out:
#    carat color clarity  depth  table     z
# 0   0.23     E     SI2   61.5   55.0  2.43
# 1   0.21     E     SI1   59.8   61.0  2.31
# 2   0.23     E     VS1   56.9   65.0  2.31
# 3   0.29     I     VS2   62.4   58.0  2.63
# 4   0.31     J     SI2   63.3   58.0  2.75

# %% [markdown]
# ## Inverse selection
# What if you want all the columns _except_ for some selection? Use the `~` operator. Only works with `X`-type selection.

# %%
# Select all columns except for carat, cut, and price
diamonds >> select(~X.carat, ~X.cut, ~X.price) >> head()
# Out:
#   color clarity  depth  table     x     y     z
# 0     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4     J     SI2   63.3   58.0  4.34  4.35  2.75

# %% [markdown]
# ## Filtering
# Filtering rows with logical criteria is done with either `mask` or `filter_by`.

# %%
diamonds >> mask(X.cut == "Ideal") >> head()
# Out:
#     carat    cut color clarity  depth  table  price     x     y     z
# 0    0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11   0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13   0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16   0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39   0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78

# %% [markdown]
# As with all things Python, multi-line statements can be placed between parentheses.

# %%
(
    diamonds
    >> filter_by(X.cut == "Ideal", X.color == "E", X.table < 55, X.price < 500)
    >> head()
)
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 26683   0.33  Ideal     E     SI2   62.2   54.0    427  4.44  4.46  2.77
# 32297   0.34  Ideal     E     SI2   62.4   54.0    454  4.49  4.52  2.81
# 40928   0.30  Ideal     E     SI1   61.6   54.0    499  4.32  4.35  2.67
# 50623   0.30  Ideal     E     SI2   62.1   54.0    401  4.32  4.35  2.69
# 50625   0.30  Ideal     E     SI2   62.0   54.0    401  4.33  4.35  2.69

# %% [markdown]
# ## Pulling
# Retrieves a column as a pandas series, if you care about a particular column at the end of your pipeline.

# %%
(
    diamonds
    >> filter_by(X.cut == "Ideal", X.color == "E", X.table < 55, X.price < 500)
    >> pull("carat")
)
# Out:
# 26683    0.33
# 32297    0.34
# 40928    0.30
# 50623    0.30
# 50625    0.30
# Name: carat, dtype: float64

# %% [markdown]
# ## Sorting
# Use `arrange`, which is a wrapper for `.sort_values` in pandas.

# %%
diamonds >> arrange(X.table, ascending=False) >> head(5)
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z
# 24932   2.01  Fair     F     SI1   58.6   95.0  13387  8.32  8.31  4.87
# 50773   0.81  Fair     F     SI2   68.8   79.0   2301  5.26  5.20  3.58
# 51342   0.79  Fair     G     SI1   65.3   76.0   2362  5.52  5.13  3.35
# 52860   0.50  Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 49375   0.70  Fair     H     VS1   62.0   73.0   2100  5.65  5.54  3.47

# %% [markdown]
# Can sort by multiple values with array notation.

# %%
diamonds >> arrange(["color", "table"], ascending=False) >> head()
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z
# 9294    1.45  Fair     J     SI2   58.6   68.0   4570  7.45  7.33  4.34
# 48505   0.74  Fair     J     VS1   58.8   68.0   1982  5.91  5.80  3.44
# 1275    0.99  Fair     J     SI1   58.0   67.0   2949  6.57  6.50  3.79
# 47531   0.75  Fair     J     VS1   61.9   67.0   1869  5.80  5.70  3.56
# 52583   0.97  Fair     J     SI2   60.8   67.0   2538  6.41  6.32  3.87

# %%
(
    diamonds
    >> group_by(X.cut)
    >> arrange(X.price)    
    >> head(3)
    >> ungroup()
    >> mask(X.carat < 0.23)    
)
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z
# 8    0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 1    0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 12   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33

# %% [markdown]
# ## Creating new columns
# Use `mutate()` to compute new columns.

# %%
diamonds >> mutate(x_plus_y=X.x + X.y) >> select(columns_from('x')) >> head(3)
# Out:
#       x     y     z  x_plus_y
# 0  3.95  3.98  2.43      7.93
# 1  3.89  3.84  2.31      7.73
# 2  4.05  4.07  2.31      8.12

# %% [markdown]
# `transmute()` to mutate and select variables.

# %%
diamonds >> transmute(x_plus_y=X.x + X.y, y_div_z=(X.y / X.z)) >> head(3)
# Out:
#    x_plus_y   y_div_z
# 0      7.93  1.637860
# 1      7.73  1.662338
# 2      8.12  1.761905

# %% [markdown]
# ## Grouping

# %%
(
    diamonds
    >> group_by(X.cut)
    >> mutate(price_lead=lead(X.price), price_lag=lag(X.price))
    >> head(2) # select 2 of each cut, since grouped
    >> select(X.cut, X.price, X.price_lead, X.price_lag)
)
# Out:
#           cut  price  price_lead  price_lag
# 8        Fair    337      2757.0        NaN
# 91       Fair   2757      2759.0      337.0
# 2        Good    327       335.0        NaN
# 4        Good    335       339.0      327.0
# 0       Ideal    326       340.0        NaN
# 11      Ideal    340       344.0      326.0
# 1     Premium    326       334.0        NaN
# 3     Premium    334       342.0      326.0
# 5   Very Good    336       336.0        NaN
# 6   Very Good    336       337.0      336.0

# %% [markdown]
# ## Summarizing

# %%
(
    diamonds
    >> group_by(X.cut)
    >> summarize(price_mean=X.price.mean(), price_std=X.price.std())
)
# Out:
#          cut   price_mean    price_std
# 0       Fair  4358.757764  3560.386612
# 1       Good  3928.864452  3681.589584
# 2      Ideal  3457.541970  3808.401172
# 3    Premium  4584.257704  4349.204961
# 4  Very Good  3981.759891  3935.862161

# %%
(
    diamonds
    >> group_by(X.cut, X.color)
    >> summarize(price_mean=X.price.mean(), price_std=X.price.std())    
)
# Out:
#    color        cut   price_mean    price_std
# 0      D       Fair  4291.061350  3286.114238
# 1      E       Fair  3682.312500  2976.651645
# 2      F       Fair  3827.003205  3223.302685
# 3      G       Fair  4239.254777  3609.644379
# 4      H       Fair  5135.683168  3886.481847
# 5      I       Fair  4685.445714  3730.271132
# 6      J       Fair  4975.655462  4050.458933
# 7      D       Good  3405.382175  3175.148710
# 8      E       Good  3423.644159  3330.702061
# 9      F       Good  3495.750275  3202.411187
# 10     G       Good  4123.482204  3702.504718
# 11     H       Good  4276.254986  4020.660488
# 12     I       Good  5078.532567  4631.702141
# 13     J       Good  4574.172638  3707.790845
# 14     D      Ideal  2629.094566  3001.069919
# 15     E      Ideal  2597.550090  2956.007149
# 16     F      Ideal  3374.939362  3766.635328
# 17     G      Ideal  3720.706388  4006.262468
# 18     H      Ideal  3889.334831  4013.375228
# 19     I      Ideal  4451.970377  4505.150405
# 20     J      Ideal  4918.186384  4476.206836
# 21     D    Premium  3631.292576  3711.634010
# 22     E    Premium  3538.914420  3794.987184
# 23     F    Premium  4324.890176  4012.022756
# 24     G    Premium  4500.742134  4356.571034
# 25     H    Premium  5216.706780  4466.189717
# 26     I    Premium  5946.180672  5053.746146
# 27     J    Premium  6294.591584  4788.936691
# 28     D  Very Good  3470.467284  3523.753268
# 29     E  Very Good  3214.652083  3408.023634
# 30     F  Very Good  3778.820240  3786.124033
# 31     G  Very Good  3872.753806  3861.375464
# 32     H  Very Good  4535.390351  4185.798202
# 33     I  Very Good  5255.879568  4687.104775
# 34     J  Very Good  5103.513274  4135.652742

# %% [markdown]
# Summarizing multiple columns with `summarize_each(function_list, *columns)`; can use your favorite indexing style for columns.

# %%
diamonds >> group_by(X.cut) >> summarize_each([np.mean, np.var], X.price, "depth", 5)
# Out:
#          cut   price_mean     price_var  depth_mean  depth_var  table_mean  \
# 0       Fair  4358.757764  1.266848e+07   64.041677  13.266319   59.053789
# 1       Good  3928.864452  1.355134e+07   62.365879   4.705224   58.694639
# 2      Ideal  3457.541970  1.450325e+07   61.709401   0.516274   55.951668
# 3    Premium  4584.257704  1.891421e+07   61.264673   1.342755   58.746095
# 4  Very Good  3981.759891  1.548973e+07   61.818275   1.900466   57.956150
#
#    table_var
# 0  15.563306
# 1   8.128253
# 2   1.553499
# 3   2.186020
# 4   4.500170
